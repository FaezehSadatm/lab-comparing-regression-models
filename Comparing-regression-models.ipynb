# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
import scipy.stats as stats
import os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
data.shape
# Out:
# (9134, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
data.columns = [data.columns[i].lower().replace(' ', '_') for i in range(len(data.columns)) ]
data.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
data = data.drop(['customer'], axis=1)
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
data['effective_to_date']
# Out:
# 0       2/24/11
# 1       1/31/11
# 2       2/19/11
# 3       1/20/11
# 4        2/3/11
#          ...
# 9129    2/10/11
# 9130    2/12/11
# 9131     2/6/11
# 9132     2/3/11
# 9133    2/14/11
# Name: effective_to_date, Length: 9134, dtype: object

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'], errors='coerce')
data['effective_to_date']
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
data['effective_year']= data['effective_to_date'].dt.year
data['effective_month']= data['effective_to_date'].dt.month
#data['day_of_week']= data['effective_to_date'].dt.day_name()
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
nulls = pd.DataFrame(data.isna().sum()*100/len(data), columns=['percentage'])
nulls.sort_values('percentage', ascending = False)
# Out:
#                                percentage
# state                                 0.0
# months_since_policy_inception         0.0
# effective_year                        0.0
# vehicle_size                          0.0
# vehicle_class                         0.0
# total_claim_amount                    0.0
# sales_channel                         0.0
# renew_offer_type                      0.0
# policy                                0.0
# policy_type                           0.0
# number_of_policies                    0.0
# number_of_open_complaints             0.0
# months_since_last_claim               0.0
# customer_lifetime_value               0.0
# monthly_premium_auto                  0.0
# marital_status                        0.0
# location_code                         0.0
# income                                0.0
# gender                                0.0
# employmentstatus                      0.0
# effective_to_date                     0.0
# ...

# %% [markdown]
# #### Dealing with numerical data

# %%
for column in data.select_dtypes(np.number).columns:
    sns.distplot(data[column])
    plt.show()

# %%
sns.boxplot(data['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount'>

# %%
log_transform = lambda x: np.log(x) if np.isfinite(x) and x != 0 else np.NAN

# %%
data1 = data.copy()

data1['total_claim_amount'] = data1['total_claim_amount'].apply(log_transform).fillna(data1['total_claim_amount'].mean())

# %%
sns.distplot(data1['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Density'>

# %% [markdown]
# #### Dealing with categorical data

# %%
categoricals = data.select_dtypes('object')
categoricals.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# ...

# %%
for column in categoricals.columns:
    plt.figure(figsize=(10,4))
    sns.barplot(x=column, y="total_claim_amount", data=data)
    plt.show()

# %%
data["coverage"] = data["coverage"].map({"Basic" : 0, "Extended" : 1, "Premium" : 2}).astype(int)

# %%
data["vehicle_size"] = data["vehicle_size"].map({"Small" : 1, "Medsize" : 2, "Large" : 3}).astype(int)

# %%
data["location_code"] = data["location_code"].map({"Rural" : 1, "Suburban" : 2, "Urban" : 3}).astype(int)

# %%
for column in categoricals.columns:
    print(data[column].value_counts(), '\n')
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# 0    5568
# 1    2742
# 2     824
# Name: coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
#
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# 2    5779
# 1    1773
# 3    1582
# Name: location_code, dtype: int64
#
# Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
#
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64
#
# Personal L3     3426
# Personal L2     2122
# ...

# %%
data['employmentstatus'].value_counts()
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64

# %%
data['employmentstatus'] = data['employmentstatus'].apply(lambda x: x if x in ['Employed', 'Unemployed'] else 'Other')

data['employmentstatus'].value_counts()
# Out:
# Employed      5698
# Unemployed    2317
# Other         1119
# Name: employmentstatus, dtype: int64

# %%
data["employmentstatus"] = data["employmentstatus"].map({"Other" : 0, "Unemployed" : 1, "Employed" : 2}).astype(int)

# %%
data['policy'].value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64

# %%
data['policy'] = data['policy'].apply(lambda x: 'Special' if x in ['Special L3','Special L2','Special L1'] else x)

data['policy'].value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Special          378
# Corporate L1     359
# Name: policy, dtype: int64

# %%
data['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: vehicle_class, dtype: int64

# %%
data['vehicle_class'] = data['vehicle_class'].apply(lambda x: 'Luxury' if x in ['Luxury SUV', 'Luxury Car'] else x)

data['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury            347
# Name: vehicle_class, dtype: int64

# %%
data.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0  Washington              2763.519279       No         0  Bachelor
# 1     Arizona              6979.535903       No         1  Bachelor
# 2      Nevada             12887.431650       No         2  Bachelor
# 3  California              7645.861827       No         0  Bachelor
# 4  Washington              2813.692575       No         0  Bachelor
#
#   effective_to_date  employmentstatus gender  income  location_code  \
# 0        2011-02-24                 2      F   56274              2
# 1        2011-01-31                 1      F       0              2
# 2        2011-02-19                 2      F   48767              2
# 3        2011-01-20                 1      M       0              2
# 4        2011-02-03                 2      M   43836              1
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    69                       32
# ...

# %%
data["Dayweek"] = data["effective_to_date"].apply(lambda x: x.weekday())
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No         0  Bachelor
# 1        Arizona              6979.535903       No         1  Bachelor
# 2         Nevada             12887.431650       No         2  Bachelor
# 3     California              7645.861827       No         0  Bachelor
# 4     Washington              2813.692575       No         0  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No         0  Bachelor
# 9130  California              3096.511217      Yes         1   College
# 9131  California              8163.890428       No         1  Bachelor
# 9132  California              7524.442436       No         1   College
# 9133  California              2611.836866       No         1   College
#
#      effective_to_date  employmentstatus gender  income  location_code  \
# ...

# %%
categoricals = data.select_dtypes('object')
categoricals.head()
# Out:
#         state response education gender marital_status     policy_type  \
# 0  Washington       No  Bachelor      F        Married  Corporate Auto
# 1     Arizona       No  Bachelor      F         Single   Personal Auto
# 2      Nevada       No  Bachelor      F        Married   Personal Auto
# 3  California       No  Bachelor      M        Married  Corporate Auto
# 4  Washington       No  Bachelor      M         Single   Personal Auto
#
#          policy renew_offer_type sales_channel  vehicle_class
# 0  Corporate L3           Offer1         Agent   Two-Door Car
# 1   Personal L3           Offer3         Agent  Four-Door Car
# 2   Personal L3           Offer1         Agent   Two-Door Car
# 3  Corporate L2           Offer1   Call Center            SUV
# 4   Personal L1           Offer1         Agent  Four-Door Car

# %%
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No         0  Bachelor
# 1        Arizona              6979.535903       No         1  Bachelor
# 2         Nevada             12887.431650       No         2  Bachelor
# 3     California              7645.861827       No         0  Bachelor
# 4     Washington              2813.692575       No         0  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No         0  Bachelor
# 9130  California              3096.511217      Yes         1   College
# 9131  California              8163.890428       No         1  Bachelor
# 9132  California              7524.442436       No         1   College
# 9133  California              2611.836866       No         1   College
#
#      effective_to_date  employmentstatus gender  income  location_code  \
# ...

# %% [markdown]
# #### Chi-square test

# %%
data_crosstab = pd.crosstab(data['policy_type'], data['policy'], margins=True)
data_crosstab
# Out:
# policy          Corporate L1  Corporate L2  Corporate L3  Personal L1  \
# policy_type
# Corporate Auto           359           595          1014            0
# Personal Auto              0             0             0         1240
# Special Auto               0             0             0            0
# All                      359           595          1014         1240
#
# policy          Personal L2  Personal L3  Special   All
# policy_type
# Corporate Auto            0            0        0  1968
# Personal Auto          2122         3426        0  6788
# Special Auto              0            0      378   378
# All                    2122         3426      378  9134

# %%
from scipy.stats import chi2_contingency

stats, p_value, dof, frequencies = chi2_contingency(data_crosstab)
p_value
# Out:
# 0.0

# %%
data.effective_month.value_counts()
# Out:
# 1    4898
# 2    4236
# Name: effective_month, dtype: int64

# %%
data.drop(['policy', 'effective_to_date', 'effective_year'], axis=1, inplace=True)
data.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0  Washington              2763.519279       No         0  Bachelor
# 1     Arizona              6979.535903       No         1  Bachelor
# 2      Nevada             12887.431650       No         2  Bachelor
# 3  California              7645.861827       No         0  Bachelor
# 4  Washington              2813.692575       No         0  Bachelor
#
#    employmentstatus gender  income  location_code marital_status  \
# 0                 2      F   56274              2        Married
# 1                 1      F       0              2         Single
# 2                 2      F   48767              2        Married
# 3                 1      M       0              2        Married
# 4                 2      M   43836              1         Single
#
#    monthly_premium_auto  months_since_last_claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %% [markdown]
# #### Removing outliers

# %%
for column in data.select_dtypes(np.number).columns:
    sns.boxplot(data[column])
    plt.show()

# %%
data1=data.copy()
data1
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No         0  Bachelor
# 1        Arizona              6979.535903       No         1  Bachelor
# 2         Nevada             12887.431650       No         2  Bachelor
# 3     California              7645.861827       No         0  Bachelor
# 4     Washington              2813.692575       No         0  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No         0  Bachelor
# 9130  California              3096.511217      Yes         1   College
# 9131  California              8163.890428       No         1  Bachelor
# 9132  California              7524.442436       No         1   College
# 9133  California              2611.836866       No         1   College
#
#       employmentstatus gender  income  location_code marital_status  \
# ...

# %%
data1[data1['customer_lifetime_value'] < 6000]
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No         0  Bachelor
# 4     Washington              2813.692575       No         0  Bachelor
# 6         Oregon              5380.898636      Yes         0   College
# 10    California              4738.992022       No         0   College
# 14    California              5384.431665       No         0   College
# ...          ...                      ...      ...       ...       ...
# 9126  California              4628.995325       No         0  Bachelor
# 9127  California              5032.165498       No         0   College
# 9128  California              4100.398533       No         2   College
# 9130  California              3096.511217      Yes         1   College
# 9133  California              2611.836866       No         1   College
#
#       employmentstatus gender  income  location_code marital_status  \
# ...

# %%
data1[data1['total_claim_amount'] < 2400]
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No         0  Bachelor
# 1        Arizona              6979.535903       No         1  Bachelor
# 2         Nevada             12887.431650       No         2  Bachelor
# 3     California              7645.861827       No         0  Bachelor
# 4     Washington              2813.692575       No         0  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No         0  Bachelor
# 9130  California              3096.511217      Yes         1   College
# 9131  California              8163.890428       No         1  Bachelor
# 9132  California              7524.442436       No         1   College
# 9133  California              2611.836866       No         1   College
#
#       employmentstatus gender  income  location_code marital_status  \
# ...

# %%
data1
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No         0  Bachelor
# 1        Arizona              6979.535903       No         1  Bachelor
# 2         Nevada             12887.431650       No         2  Bachelor
# 3     California              7645.861827       No         0  Bachelor
# 4     Washington              2813.692575       No         0  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No         0  Bachelor
# 9130  California              3096.511217      Yes         1   College
# 9131  California              8163.890428       No         1  Bachelor
# 9132  California              7524.442436       No         1   College
# 9133  California              2611.836866       No         1   College
#
#       employmentstatus gender  income  location_code marital_status  \
# ...

# %%
data.corr()['total_claim_amount'].sort_values()
# Out:
# income                          -0.355254
# employmentstatus                -0.257407
# vehicle_size                    -0.073799
# number_of_open_complaints       -0.014241
# number_of_policies              -0.002354
# months_since_policy_inception    0.003335
# Dayweek                          0.004977
# effective_month                  0.006820
# months_since_last_claim          0.007563
# customer_lifetime_value          0.226451
# location_code                    0.254766
# coverage                         0.279078
# monthly_premium_auto             0.632017
# total_claim_amount               1.000000
# Name: total_claim_amount, dtype: float64

# %%
data1.corr()['total_claim_amount'].sort_values()
# Out:
# income                          -0.355254
# employmentstatus                -0.257407
# vehicle_size                    -0.073799
# number_of_open_complaints       -0.014241
# number_of_policies              -0.002354
# months_since_policy_inception    0.003335
# Dayweek                          0.004977
# effective_month                  0.006820
# months_since_last_claim          0.007563
# customer_lifetime_value          0.226451
# location_code                    0.254766
# coverage                         0.279078
# monthly_premium_auto             0.632017
# total_claim_amount               1.000000
# Name: total_claim_amount, dtype: float64

# %%
data = pd.get_dummies(data)
data
# Out:
#       customer_lifetime_value  coverage  employmentstatus  income  \
# 0                 2763.519279         0                 2   56274
# 1                 6979.535903         1                 1       0
# 2                12887.431650         2                 2   48767
# 3                 7645.861827         0                 1       0
# 4                 2813.692575         0                 2   43836
# ...                       ...       ...               ...     ...
# 9129             23405.987980         0                 2   71941
# 9130              3096.511217         1                 2   21604
# 9131              8163.890428         1                 1       0
# 9132              7524.442436         1                 2   21941
# 9133              2611.836866         1                 1       0
#
#       location_code  monthly_premium_auto  months_since_last_claim  \
# 0                 2                    69                       32
# ...

# %% [markdown]
# #### 1. In this final lab, we will model our data. Import sklearn train_test_split and separate the data.

# %%
from sklearn.model_selection import train_test_split

X = data.drop('total_claim_amount', axis=1)
y = data['total_claim_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

X_train_num = X_train.select_dtypes(np.number)
X_test_num = X_test.select_dtypes(np.number)

# %% [markdown]
# #### 2. Try a simple linear regression with all the data to see whether we are getting good results.

# %% [markdown]
# #### Runnig the model with data:

# %%
from sklearn.preprocessing import StandardScaler
import pickle

transformer = StandardScaler()
transformer.fit(X_train_num)

with open('std_transformer.pickle', 'wb') as file:
    pickle.dump(transformer, file)
    
with open('std_transformer.pickle', 'rb') as file:
    loaded_transformer = pickle.load(file)

X_train_ = loaded_transformer.transform(X_train_num)
X_test_ = loaded_transformer.transform(X_test_num)

unscaled_X_train = loaded_transformer.inverse_transform(X_train_)

unscaled_X_train[0][0]
# Out:
# 4768.955924

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.6129620979478678

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_score(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False)
# Out:
# (0.6129620979478678, 128.80959320499107, 175.42458895217365)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score

# %%
models = []

models.append(("LinearRegression",LinearRegression()))
models.append(("KNeighbors",KNeighborsRegressor()))
models.append(("MLPRegressor",MLPRegressor()))


results = []
names = []
for name,model in models:
    result = cross_val_score(model, X_test, y_test,  cv=3)
    names.append(name)
    results.append(result)

# %%
for i in range(len(names)):
    print(names[i],results[i])
# Out:
# LinearRegression [0.59375276 0.58436869 0.61410818]
# KNeighbors [0.10637416 0.04462107 0.04341785]
# MLPRegressor [0.40158007 0.41575222 0.33651822]

# %% [markdown]
# #### Runnig the model with data1:

# %%
data1 = pd.get_dummies(data)
data1
# Out:
#       customer_lifetime_value  coverage  employmentstatus  income  \
# 0                 2763.519279         0                 2   56274
# 1                 6979.535903         1                 1       0
# 2                12887.431650         2                 2   48767
# 3                 7645.861827         0                 1       0
# 4                 2813.692575         0                 2   43836
# ...                       ...       ...               ...     ...
# 9129             23405.987980         0                 2   71941
# 9130              3096.511217         1                 2   21604
# 9131              8163.890428         1                 1       0
# 9132              7524.442436         1                 2   21941
# 9133              2611.836866         1                 1       0
#
#       location_code  monthly_premium_auto  months_since_last_claim  \
# 0                 2                    69                       32
# ...

# %%
from sklearn.model_selection import train_test_split

X = data1.drop('total_claim_amount', axis=1)
y = data1['total_claim_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

X_train_num = X_train.select_dtypes(np.number)
X_test_num = X_test.select_dtypes(np.number)

# %%
from sklearn.preprocessing import StandardScaler
import pickle

transformer = StandardScaler()
transformer.fit(X_train_num)

with open('std_transformer.pickle', 'wb') as file:
    pickle.dump(transformer, file)
    
with open('std_transformer.pickle', 'rb') as file:
    loaded_transformer = pickle.load(file)

X_train_ = loaded_transformer.transform(X_train_num)
X_test_ = loaded_transformer.transform(X_test_num)

unscaled_X_train = loaded_transformer.inverse_transform(X_train_)

unscaled_X_train[0][0]
# Out:
# 4768.955924

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.6129620979478678

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_score(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False)
# Out:
# (0.6129620979478678, 128.80959320499107, 175.42458895217365)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score

# %%
models = []

models.append(("LinearRegression",LinearRegression()))
models.append(("KNeighbors",KNeighborsRegressor()))
models.append(("MLPRegressor",MLPRegressor()))


results = []
names = []
for name,model in models:
    result = cross_val_score(model, X_test, y_test,  cv=3)
    names.append(name)
    results.append(result)

# %%
for i in range(len(names)):
    print(names[i],results[i])
# Out:
# LinearRegression [0.59375276 0.58436869 0.61410818]
# KNeighbors [0.10637416 0.04462107 0.04341785]
# MLPRegressor [0.40439342 0.39716323 0.46928086]
